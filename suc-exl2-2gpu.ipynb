# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/turboderp/exllamav2

# %%
# !pip install exllamav2

# %%
# !git clone -b  4.0bpw https://huggingface.co/turboderp/Llama-3.2-3B-exl2
# Out:
# Cloning into 'Llama-3.2-3B-exl2'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 50 (delta 14), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (50/50), 2.30 MiB | 4.09 MiB/s, done.

# %%
# %cd /content/exllamav2

# %%
# !git lfs install

# %%
/kaggle/working/command-r-v01-35B-exl2

# %%
# %cd /content/exllamav2
# !python /kaggle/working/exllamav2/test_inference.py -m /kaggle/working/Llama-3.2-3B-exl2 -p "Who is Napoleon Bonaparte?" --tokens 22 -tp -gs auto
# Out:
# [Errno 2] No such file or directory: '/content/exllamav2'
# /kaggle/working
#  -- Model: /kaggle/working/Llama-3.2-3B-exl2
#  -- Options: ['gpu_split: auto', 'tensor_parallel']
# Loading: /kaggle/working/Llama-3.2-3B-exl2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:05 0:00:00m 0:00:01
#  -- Loading tokenizer...
#  -- Warmup...
#  -- Generating...
#
# Who is Napoleon Bonaparte?
# Napoleon Bonaparte was a French military and political leader serving as the first consul of the French
#
#  -- Response generated in 2.05 seconds, 22 tokens, 10.74 tokens/second (includes prompt eval.)

# %%
# %cd /content/exllamav2
# !python /kaggle/working/exllamav2/test_inference.py -m /kaggle/working/Llama-3.2-3B-exl2 -p "Who is Napoleon Bonaparte?" --tokens 512 -tp -gs auto
# Out:
# [Errno 2] No such file or directory: '/content/exllamav2'
# /kaggle/working
#  -- Model: /kaggle/working/Llama-3.2-3B-exl2
#  -- Options: ['gpu_split: auto', 'tensor_parallel']
# Loading: /kaggle/working/Llama-3.2-3B-exl2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:02 0:00:00m 0:00:01
#  -- Loading tokenizer...
#  -- Warmup...
#  -- Generating...
#
# Who is Napoleon Bonaparte?
# Who Was Napoleon Bonaparte?
# Napoleon Bonaparte was a great general and the first emperor of France during the French Revolution. His last name, "Bonaparte," means "good people" in Italian. When he became the first Emperor of France, his advisors called him "the Little Corporal," but the people of France referred to him as "the Little Emperor."
# Life of Napoleon Bonaparte
# ...

# %%
# !rm -rf /kaggle/working/Llama-3.2-3B-exl2

# %%
ls -lah /kaggle/working/gemma-3-27b-it-exl2
# Out:
# total 3.1G
# drwxr-xr-x 3 root root 4.0K Mar 18 21:47 ./
# drwxr-xr-x 5 root root 4.0K Mar 18 21:44 ../
# -rw-r--r-- 1 root root   35 Mar 18 21:44 added_tokens.json
# -rw-r--r-- 1 root root 1.6K Mar 18 21:44 chat_template.json
# -rw-r--r-- 1 root root 1.4K Mar 18 21:57 config.json
# -rw-r--r-- 1 root root  192 Mar 18 21:44 generation_config.json
# drwxr-xr-x 9 root root 4.0K Mar 18 21:47 .git/
# -rw-r--r-- 1 root root 1.6K Mar 18 21:44 .gitattributes
# -rw-r--r-- 1 root root 3.4M Mar 18 21:44 measurement.json
# -rw-r--r-- 1 root root 124K Mar 18 21:44 model.safetensors.index.json
# -rw-r--r-- 1 root root 2.7G Mar 18 21:46 output-00001-of-00003.safetensors
# -rw-r--r-- 1 root root    0 Mar 18 21:47 output-00002-of-00003.safetensors
# -rw-r--r-- 1 root root 399M Mar 18 21:44 output-00003-of-00003.safetensors
# -rw-r--r-- 1 root root  570 Mar 18 21:44 preprocessor_config.json
# -rw-r--r-- 1 root root   70 Mar 18 21:44 processor_config.json
# ...

# %%
import json

# مسار ملف config.json
config_path = "/kaggle/working/gemma-3-27b-it-exl2/config.json"

# تحميل الملف
with open(config_path, "r", encoding="utf-8") as f:
    config = json.load(f)

# إضافة vocab_size إذا لم يكن موجودًا
if "vocab_size" not in config["text_config"]:
    config["text_config"]["vocab_size"] = 256000  # ✅ تعديل هنا

# حفظ الملف بعد التعديل
with open(config_path, "w", encoding="utf-8") as f:
    json.dump(config, f, indent=4)

print("✅ تم تعديل الملف بنجاح!")

# %%
import json

# مسار ملف config.json
config_path = "/kaggle/working/gemma-3-27b-it-exl2/config.json"

# تحميل الملف
with open(config_path, "r", encoding="utf-8") as f:
    config = json.load(f)

# إضافة rms_norm_eps إذا لم يكن موجودًا
if "rms_norm_eps" not in config["text_config"]:
    config["text_config"]["rms_norm_eps"] = 1e-5  # ✅ القيمة الصحيحة

# حفظ الملف بعد التعديل
with open(config_path, "w", encoding="utf-8") as f:
    json.dump(config, f, indent=4)

print("✅ تم تعديل الملف بنجاح!")

# %%
# !python /kaggle/working/exllamav2/test_inference.py -m /kaggle/working/gemma-3-27b-it-exl2 -p "Who is Napoleon Bonaparte?"
# Out:
#  -- Model: /kaggle/working/gemma-3-27b-it-exl2
#  -- Options: []
#  !! Warning, unknown architecture: Gemma3ForConditionalGeneration
#  !! Loading as LlamaForCausalLM
# Traceback (most recent call last):
#   File "/kaggle/working/exllamav2/test_inference.py", line 100, in <module>
#     model, tokenizer = model_init.init(
#   File "/kaggle/working/exllamav2/exllamav2/model_init.py", line 98, in init
#     config.prepare()
#   File "/kaggle/working/exllamav2/exllamav2/config.py", line 413, in prepare
#     f = STFile.open(st_file, keymap = self.arch.keymap)
#   File "/kaggle/working/exllamav2/exllamav2/stloader.py", line 77, in open
#     global_stfiles[filename] = STFile(filename, keymap)
#   File "/kaggle/working/exllamav2/exllamav2/stloader.py", line 54, in __init__
#     self.read_dict()
#   File "/kaggle/working/exllamav2/exllamav2/stloader.py", line 90, in read_dict
#     header_size = np.fromfile(fp, dtype = np.int64, count = 1).item()
# ...
